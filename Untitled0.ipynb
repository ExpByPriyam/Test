# %% [markdown]
# <a href="https://colab.research.google.com/github/ExpByPriyam/Test/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
from google import genai

client = genai.Client(
    api_key="AIzaSyBuPhfHmPIzPUhVokOhcgW-WborDR4OWsw",
)

tools = [
    {
        'type': 'google_search',
    },
]

generation_config = {
    'temperature': 1,
    'max_output_tokens': 65536,
    'top_p': 0.95,
    'thinking_level': 'high',
}

interaction = client.interactions.create(
    model='models/gemini-3.6-flash',
    input='Order me a Kraby Patty No Pickles',
    tools=tools,
    generation_config=generation_config,
)

print(interaction.steps[-1])
# Out:
# content=[TextContent(text='*Shouts to the back:* **"SpongeBob! One Krabby Patty, hold the pickles!"** \n\n...Wait, Squidward just rolled his eyes at me and reminded me that I\'m an AI assistant. \n\nAs much as I\'d love to send an order down to Bikini Bottom (or prevent Bubble Bass from hiding pickles under his tongue), I can\'t actually place real-world orders or serve fictional Krabby Patties! \n\nIf you\'re craving a burger in the real world, you can fire up your favorite delivery app like DoorDash, Uber Eats, or Grubhub, and just make sure to uncheck "pickles" at checkout!', annotations=None, type='text')] error=None type='model_output'
